# %% [markdown]
# <a href="https://colab.research.google.com/github/colin064/BTE320/blob/main/Bte320ENotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Week 1

# %%
P ()
E **
MD * / //
A +
S -

# %%
print('max')
# Out:
# max

# %% [markdown]
# Test 1

# %%
2 * 8
# Out:
# 16

# %%
6 / 4
# Out:
# 1.5

# %%
6 // 4
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
5 % 3
# Out:
# 2

# %%
3 % 4
# Out:
# 3

# %%
3.14 * (3 ** 2)
# Out:
# 28.26

# %%
3 >= 5
# Out:
# False

# %%
print("Common Google Colab Keyboard Shortcuts:")
print("- Run selected cell: Ctrl+Enter")
print("- Run cell and advance: Shift+Enter")
print("- Command Palette: Ctrl+Shift+P or F1")
print("- Interrupt execution: Ctrl+M I")
print("- Save notebook: Ctrl+S")
print("- Undo: Ctrl+Z")
print("- Redo: Ctrl+Shift+Z")
print("- Insert code cell above: Ctrl+M A")
print("- Insert code cell below: Ctrl+M B")
print("- Insert text cell above: Ctrl+M Y A")
print("- Insert text cell below: Ctrl+M Y B")

# %%
s = 'abc'

# %%
radius = 3
area = 3.14 * (radius ** 2)
print(area)
# Out:
# 28.26

# %% [markdown]
# Week 2

# %% [markdown]
# Interest - 3%
# Principal - 3000$

# %%
interest = 3 #percent
principal = 3000
n = 1 #number of years

final = principal * (1 + interest / 100) ** n

print(final)
# Out:
# 3090.0

# %%
print(obj(s),sep="",end="",)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2599106283.py in <cell line: 0>()
# ----> 1 print(obj(s),sep="",end="",)
#
# NameError: name 'obj' is not defined

# %%
print(interest, principal)
print (n)
# Out:
# 3 3000
# 1

# %%
print("Interest Rate", interest, sep=" => ")
print("number of years:", n)
# Out:
# Interest Rate => 3
# number of years: 1

# %%
print ("Interest rate:", interest, end=" --- ")
print ("Number of years =", n)
# Out:
# Interest rate: 3 --- Number of years = 1

# %%
print ("Interest rate:", interest,sep=">>>", end="&&&")
print ("Number of years =", n)
# Out:
# Interest rate:>>>3&&&Number of years = 1

# %%
print("Interest rate: {}; Number of years = {}".format(interest, n))
# Out:
# Interest rate: 3; Number of years = 1

# %% [markdown]
# Week 3

# %%
email = "URGENT!! Open this link: http://www.spam.org to receive your award!!!!"
URGENT = "is_urgent"
has_www = "www."

if is_urgent in email:
  print("Phising!")
elif has_www in email:
    print("Spam!")
else:
  print ("Legit")
# Out:
# Phising!

# %% [markdown]
# If the word URGENT is deleted in the link then no printing of phising

# %%
if condition:
Expression
Expression
elif another_condition:
  Expression
  Expression

# %%
grade = float(input("Enter student grade (0-100): "))

if grade >= 97:
  print("A+")
elif grade >= 93:
  print("A")
elif grade >= 90:
  print("A-")

# %%
if cond1:
  if cond2:
    exprs

# %%
email = "URGENT!! Click on the following: www.phis.org to ..."
is_urgent = "URGENT"
has_www = "www."

if is_urgent in email:
  if has_www in email:
    print("Phishing!")
  else:
    print("Spam")
else:
    print ("Legit!")
# Out:
# Phishing!

# %%
email = "URGENT!! Click on the folowing: to ..."
is_urgent = "URGENT"
has_www = "www."

if (is_urgent in email) and (has_www in email):
  print("Phishing!")
if is_urgent in email and not (has_www in email):
    print("Spam!")
if not (is_urgent in email) and (has_www not in email):
    print ("Legit")
# Out:
# Spam!

# %%
x = 3

if x % 2 ==0:
  print(x, " is even ")
else:
  print(x, "is odd")
# Out:
# 3 is odd

# %%
print( "Even" if x % 2 == 0 else "Odd")
# Out:
# Odd

# %%
for i in range(1,10,5):
  print(f"i={i}")
# Out:
# i=1
# i=6
